# %% [markdown]
# <a href="https://colab.research.google.com/github/sechan-design/2026-data-science-and-machine-learning/blob/main/ARIMAX_%EB%AA%A8%EB%8D%B8_no_cpi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("forecast")
library(forecast)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘colorspace’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘urca’, ‘zoo’, ‘RcppArmadillo’

# %%
data <- read.csv('통합데이터.csv')

# %%
y <- ts(data$high)
x <-data$high.popu

# %%
model = auto.arima(y, xreg= x)
summary(model)
# Out:
# Series: y
# Regression with ARIMA(2,0,1) errors
#
# Coefficients:
#          ar1      ar2     ma1  intercept     xreg
#       1.3815  -0.8153  0.3700    90.1232  -0.0345
# s.e.  0.1845   0.1698  0.2663     6.0069   0.0034
#
# sigma^2 = 2.033:  log likelihood = -32.88
# AIC=77.76   AICc=84.76   BIC=83.43
#
# Training set error measures:
#                      ME     RMSE       MAE        MPE     MAPE      MASE
# Training set 0.03618231 1.223819 0.9816638 0.03135628 3.117201 0.5106921
#                      ACF1
# Training set -0.004683523

# %%
dy <-diff(y)
dx <-diff(x)

model_diff = auto.arima(dy,xreg=dx)

# %%
lm_model <-lm(y ~ x1)
summary(lm_model)
# Out:
# Error in eval(predvars, data, env): object 'x1' not found
# Traceback:
#
# 1. eval(mf, parent.frame())
# 2. eval(mf, parent.frame())
# 3. stats::model.frame(formula = y ~ x1, drop.unused.levels = TRUE)
# 4. model.frame.default(formula = y ~ x1, drop.unused.levels = TRUE)
# 5. eval(predvars, data, env)
# 6. eval(predvars, data, env)
# 7. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'x1' not found", base::quote(eval(predvars, data,
#  .     env)))
