# %% [markdown]
# <a href="https://colab.research.google.com/github/sechan-design/2026-data-science-and-machine-learning/blob/main/%EC%9C%A4%EC%84%B8%EC%B0%AC_%EC%83%81%EA%B4%80%EA%B4%80%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ⅱ-2-2 상관관계
# ### [기본 활동] 두 변수 간의 관계를 시각화하기

# %% [markdown]
# - 관계의 시각화
# <br>
# 서로 다른 두 변수 간의 관계를 살펴보기 위해 2019년도 3월 대구광역시의 일조 시간과 평균 전운량에 대한 CSV 파일을 이용해 보자.
# <br>

# %% [markdown]
# ### (활동1) 데이터를 산점도로 나타내기

# %% [markdown]
# [설명]
#
# - 2025년 제주특별자치도의 일조 시간과 평균 전운량의 산점도를 x축은 평균 전운량, y축은 합계 일조 시간으로 설정하여 표현해 보자.

# %% [markdown]
# ---
#
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# [소스 코드]

# %% [markdown]
# 1. 코드를 실행하고 컴퓨터에 저장된 CSV 예제 파일을 업로드한다.

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 97.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload() #컴퓨터에 저장된 파일 경로 지정하여 업로드하기
csv_file = '/content/2025 제주 일조 시간과 평균 전운량.csv'
# Out:
#      <input type="file" id="files-0a30337f-5049-464d-8509-ab2724716a06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a30337f-5049-464d-8509-ab2724716a06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2. 업로드한 2019년 3월 대구광역시 일조 시간과 평균 전운량 CSV 파일을 판다스
# 라이브러리를 이용하여 읽어온 다음 출력한다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(csv_file, encoding ='cp949')
print(df)
df
# Out:
#        지점  지점명          일시  합계 일조시간(hr)  평균 전운량(1/10)
# 0     184   제주  2025-01-01          5.8           4.4
# 1     184   제주  2025-01-02          4.8           3.5
# 2     184   제주  2025-01-03          3.2           4.9
# 3     184   제주  2025-01-04          5.1           5.1
# 4     184   제주  2025-01-05          0.0           9.6
# ...   ...  ...         ...          ...           ...
# 1455  189  서귀포  2025-12-27          1.6           6.0
# 1456  189  서귀포  2025-12-28          7.0           4.3
# 1457  189  서귀포  2025-12-29          4.7           3.0
# 1458  189  서귀포  2025-12-30          8.1           3.0
# 1459  189  서귀포  2025-12-31          8.5           5.0
#
# [1460 rows x 5 columns]
#        지점  지점명          일시  합계 일조시간(hr)  평균 전운량(1/10)
# 0     184   제주  2025-01-01          5.8           4.4
# 1     184   제주  2025-01-02          4.8           3.5
# 2     184   제주  2025-01-03          3.2           4.9
# 3     184   제주  2025-01-04          5.1           5.1
# ...

# %%
plt.hist(df['합계 일조시간(hr)'])
# Out:
# (array([311., 121., 100., 116., 131., 155., 188., 152., 113.,  73.]),
#  array([ 0.  ,  1.36,  2.72,  4.08,  5.44,  6.8 ,  8.16,  9.52, 10.88,
#         12.24, 13.6 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 3. 업로드한 2025년 제주특별자치도 일조 시간과 평균 전운량 데이터세트에서 ‘합계
# 일조 시간(hr)’ 컬럼을 출력한다.

# %% [markdown]
# 4. scatter( ) 함수를 이용하여 x축에는 평균 전운량, y축에는 합계 일조 시간을 나타
# 내는 산점도를 출력하고 결과를 해석한다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib



plt.xlabel("평균 전운량")
plt.ylabel("합계 일조시간(hr)")
plt.scatter(df['평균 전운량(1/10)'],df['합계 일조시간(hr)'])

# %% [markdown]
# #데이터를 해석하고 나만의 결론을 도출해보기

# %% [markdown]
# ### (활동2) 상관계수 구하기

# %% [markdown]
# 1. 컴퓨터에 저장된 2025년 제주특별자치도 일조 시간과 평균 전운량 CSV 파일을 업로드한다.

# %%
from google.colab import files
uploaded = files.upload() #컴퓨터에 저장된 파일 경로 지정하여 업로드하기
csv_file = '/content/2025 제주 일조 시간과 평균 전운량.csv'

# %% [markdown]
# 2. 업로드한 데이터세트를 읽어온 다음 피어슨 상관계수를 구하는 코드를 작성한다.

# %%
import pandas as pd
df = pd.read_csv(csv_file, encoding ='cp949')
r = df['평균 전운량(1/10)'].corr(df['합계 일조시간(hr)'],method='spearman')
print(f"스피어만 상관계수:{r}")
# Out:
# 스피어만 상관계수:-0.8466032696031998

# %% [markdown]
# 3. 업로드한 데이터세트를 읽어온 다음 스피어먼 상관계수를 구하는 코드를 작성하
# 고 결과를 해석한다.

# %% [markdown]
# ### (활동3) 공공 데이터를 사용하여 인구 총계 남자와 여자라는 두 변수 간의 관련성을 산점도로 표현하고 상관계수 구하기

# %% [markdown]
# 1. 제주특별자치도 제주시 주민등록인구 통계 현황 공공 데이터를 사용하여 인구 총계 남자(총계 남)와 여자(총계 여)라는 두 변수 간의 관련성을 산점도로 표현한다.

# %%
from google.colab import files
uploaded = files.upload() #컴퓨터에 저장된 파일 경로 지정하여 업로드하기
csv_file = '/content/2025연령별인구현황_제주시.csv'
# Out:
#      <input type="file" id="files-576b9d9a-d073-4051-b45e-536d3589cf22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-576b9d9a-d073-4051-b45e-536d3589cf22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(csv_file,thousands=',',encoding='cp949')
df
# Out:
#        총계   총계남   총계여       Unnamed: 3  제주특별자치도 제주시 한림읍(5011025000)  \
# 0    2565  1330  1235       2025년_남_0세                           28
# 1    2502  1251  1251       2025년_남_1세                           28
# 2    2569  1274  1295       2025년_남_2세                           35
# 3    2824  1450  1374       2025년_남_3세                           44
# 4    3006  1536  1470       2025년_남_4세                           51
# ..    ...   ...   ...              ...                          ...
# 96    224    29   195      2025년_남_96세                            2
# 97    120    11   109      2025년_남_97세                            1
# 98     88     9    79      2025년_남_98세                            1
# 99     61     6    55      2025년_남_99세                            2
# 100   137     6   131  2025년_남_100세 이상                            1
#
#      제주특별자치도 제주시 애월읍(5011025300)  제주특별자치도 제주시 구좌읍(5011025600)  \
# 0                             80                           15
# ...

# %%
plt.scatter(df['총계남'],df['총계여'])

# %% [markdown]
# #데이터를 해석하고 나만의 결론을 도출해보기

# %% [markdown]
# 3. 인구 총계 남자(총계 남)와 여자(총계 여)라는 두 변수 간의 관련성을 피어슨, 스피어먼 상관계수로 구한다.

# %%
from google.colab import files
uploaded = files.upload() # 컴퓨터에 저장된 파일 경로 지정 후 업로드
csv_file = '/content/2025연령별인구현황_제주시.csv'
import pandas as pd
import matplotlib.pyplot as plt

r=df['총계남'].corr(df['총계여'],method='spearman')
# Out:
#      <input type="file" id="files-66b76f05-84ee-4e48-9d92-da99cc47d709" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66b76f05-84ee-4e48-9d92-da99cc47d709">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(r)
# Out:
# 0.9906114224483628
