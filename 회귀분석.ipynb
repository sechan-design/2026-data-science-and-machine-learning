# %% [markdown]
# <a href="https://colab.research.google.com/github/sechan-design/2026-data-science-and-machine-learning/blob/main/%ED%9A%8C%EA%B7%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/2025 제주 일조 시간과 평균 전운량.csv", encoding="euc-kr")
df.dropna(axis=0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1459 entries, 0 to 1459
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   지점            1459 non-null   int64
#  1   지점명           1459 non-null   object
#  2   일시            1459 non-null   object
#  3   합계 일조시간(hr)   1459 non-null   float64
#  4   평균 전운량(1/10)  1459 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 68.4+ KB

# %%
x=np.array(df['평균 전운량(1/10)']).reshape(-1,1)
y=np.array(df['합계 일조시간(hr)']).reshape(-1,1)
model = LinearRegression().fit(x,y)
print("기울기:",model.coef_,"절편:",model.intercept_)
# Out:
# 기울기: [[-1.1790922]] 절편: [12.39250359]

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 57.7 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib
plt.xlabel("평균 전운량(1/10)")
plt.ylabel("합계일조시간")
plt.scatter(x,y)
b0 = model.intercept_[0]
b1 = model.coef_[0]
plt.plot(x,b0+b1*x,'r')
