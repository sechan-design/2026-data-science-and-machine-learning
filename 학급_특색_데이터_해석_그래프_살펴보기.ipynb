# %% [markdown]
# <a href="https://colab.research.google.com/github/sechan-design/2026-data-science-and-machine-learning/blob/main/%ED%95%99%EA%B8%89_%ED%8A%B9%EC%83%89_%EB%8D%B0%EC%9D%B4%ED%84%B0_%ED%95%B4%EC%84%9D_%EA%B7%B8%EB%9E%98%ED%94%84_%EC%82%B4%ED%8E%B4%EB%B3%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 7 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (5,337 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 코랩용 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
from google.colab import files
uploaded = files.upload()
csv_file = '학령인구수'
# Out:
#      <input type="file" id="files-ee2ad491-8a7e-4a73-bf0d-9ec5490627fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee2ad491-8a7e-4a73-bf0d-9ec5490627fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
csv_file = '학령인구수.csv'
po = pd.read_csv(csv_file, encoding ='cp949')
po
# Out:
#       연도   초등학교   중학교    고등학교     총합
# 0   2007  3,808  2,095  1,966  7,869
# 1   2008  3,631  2,070  2,039  7,740
# 2   2009  3,446  2,034  2,089  7,569
# 3   2010  3,280  1,985  2,084  7,349
# 4   2011  3,109  1,914  2,062  7,085
# 5   2012  2,926  1,867  2,028  6,821
# 6   2013  2,783  1,818  1,985  6,586
# 7   2014  2,751  1,719  1,912  6,382
# 8   2015  2,720  1,578  1,868  6,166
# 9   2016  2,688  1,458  1,816  5,962
# 10  2017  2,719  1,385  1,715  5,819
# 11  2018  2,756  1,340  1,574  5,670
# 12  2019  2,766  1,319  1,453  5,538
# 13  2020  2,724  1,364  1,390  5,478
# 14  2021  2,720  1,380  1,344  5,444
# 15  2022  2,701  1,368  1,323  5,392
# 16  2023  2,607  1,364  1,364  5,335
# 17  2024  2,485  1,384  1,379  5,248
# 18  2025  2,344  1,403  1,367  5,114

# %%
po['총합'] = po['총합'].str.replace(',', '').astype(int)

# %%
# 학령인구수 데이터 시각화(그래프 그리기)

plt.figure(figsize=(12, 6))
plt.bar(po['연도'], po['총합'], color='skyblue', edgecolor='black')

plt.title('연도별 학령인구수', fontsize=16)
plt.xlabel('연도', fontsize=14)
plt.ylabel('총합(천명)', fontsize=14)
plt.xticks(po['연도'], rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
po['고등학교'] = po['고등학교'].str.replace(',', '').astype(int)

# %%
# 학령인구수 데이터 시각화(그래프 그리기)

plt.figure(figsize=(12, 6))
plt.bar(po['연도'], po['고등학교'], color='skyblue', edgecolor='black')

plt.title('연도별 고등학교 학령인구수', fontsize=16)
plt.xlabel('연도', fontsize=14)
plt.ylabel('고등학생 수(천명)', fontsize=14)
plt.xticks(po['연도'], rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
csv_file = '월평균 사교육비'
# Out:
#      <input type="file" id="files-06cbba68-e729-48ac-8108-ff01a30e0f81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06cbba68-e729-48ac-8108-ff01a30e0f81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
csv_file = '월평균 사교육비.csv'
money = pd.read_csv(csv_file, encoding ='cp949')
money
# Out:
#       연도    전체  초등학교   중학교  고등학교
# 0   2007  22.2  22.7  23.4  19.7
# 1   2008  23.3  24.2  24.1  20.6
# 2   2009  24.2  24.5  26.0  21.7
# 3   2010  24.0  24.5  25.5  21.8
# 4   2011  24.0  24.1  26.2  21.8
# 5   2012  23.6  21.9  27.6  22.4
# 6   2013  23.9  23.2  26.7  22.3
# 7   2014  24.2  23.2  27.0  23.0
# 8   2015  24.4  23.1  27.5  23.6
# 9   2016  25.6  24.1  27.5  26.2
# 10  2017  27.2  25.3  29.1  28.5
# 11  2018  29.1  26.3  31.2  32.1
# 12  2019  32.1  29.0  33.8  36.5
# 13  2020  30.2  23.5  34.2  39.6
# 14  2021  36.7  32.8  39.2  41.9
# 15  2022  41.0  37.2  43.8  46.0
# 16  2023  43.4  39.8  44.9  49.1
# 17  2024  47.4  44.2  49.0  52.0
# 18  2025  45.8  43.3  46.1  49.9

# %%
#월평균 사교육비 데이터 시각화(그래프 그리기)
plt.figure(figsize=(12, 7))

plt.plot(money['연도'], money['전체'], marker='o', label='전체')
plt.plot(money['연도'], money['초등학교'], marker='o', label='초등학교')
plt.plot(money['연도'], money['중학교'], marker='o', label='중학교')
plt.plot(money['연도'], money['고등학교'], marker='o', label='고등학교')

plt.title('연도별 월평균 사교육비', fontsize=16)
plt.xlabel('연도', fontsize=14)
plt.ylabel('월평균 사교육비 (만원)', fontsize=14)
plt.xticks(money['연도'], rotation=45, ha='right')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# 고등학생만
plt.figure(figsize=(12, 7))

plt.plot(money['연도'], money['고등학교'], marker='o', label='고등학교')

plt.title('연도별 월평균 사교육비', fontsize=16)
plt.xlabel('연도', fontsize=14)
plt.ylabel('월평균 사교육비 (만원)', fontsize=14)
plt.xticks(money['연도'], rotation=45, ha='right')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
uploaded = files.upload()
csv_file = '소비자물가지수'
# Out:
#      <input type="file" id="files-29d73044-da59-4425-acd4-244c4106c329" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29d73044-da59-4425-acd4-244c4106c329">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
csv_file = '소비자물가지수.csv'
cpi = pd.read_csv(csv_file, encoding ='cp949')
cpi
# Out:
#     year    cpi
# 0   2007   78.0
# 1   2008   81.7
# 2   2009   83.9
# 3   2010   86.4
# 4   2011   89.9
# 5   2012   91.8
# 6   2013   93.0
# 7   2014   94.2
# 8   2015   94.9
# 9   2016   95.8
# 10  2017   97.6
# 11  2018   99.1
# 12  2019   99.5
# 13  2020  100.0
# 14  2021  102.5
# 15  2022  107.7
# 16  2023  111.6
# 17  2024  114.2
# 18  2025  116.6

# %%
plt.figure(figsize=(12, 7))

plt.plot(cpi['year'], cpi['cpi'], marker='o', label='소비자물가지수')

plt.title('연도별 소비자물가지수', fontsize=16)
plt.xlabel('연도', fontsize=14)
plt.ylabel('소비자물가지수(2020=100%)', fontsize=14)
plt.xticks(money['연도'], rotation=45, ha='right')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
