# %% [markdown]
# <a href="https://colab.research.google.com/github/sechan-design/2026-data-science-and-machine-learning/blob/main/%EC%9C%A4%EC%84%B8%EC%B0%AC_IT_%EC%A7%81%EB%AC%B4%EB%B3%84_%EC%9E%84%EA%B8%88_%EB%B6%84%EC%84%9D_(%ED%95%99%EC%83%9D_%EC%8B%A4%EC%8A%B5%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 5 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,322 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 코랩용 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# 데이터 세트 생성
data = {
    '직무': ['IT기획자', 'IT컨설턴트', '업무분석가', '데이터분석가', 'IT PM',
           'IT아키텍트', 'UI/UX기획/개발자', 'UI/UX디자이너', '응용SW개발자',
           '시스템SW개발자', '정보시스템운용자', 'IT지원기술자', 'IT마케터',
           'IT품질관리자', 'IT테스터', 'IT감리', '정보보안전문가'],
    '2022': [419656, 476007, 544972, 347476, 463265, 518084, 291414, 217843, 311962, 247590, 326653, 190219, 378726, 402626, 208959, 456540, 362961],
    '2023': [481654, 476404, 532956, 380190, 456225, 534135, 315898, 224150, 341404, 278819, 435608, 215203, 483647, 442826, 189146, 485624, 454136],
    '2024': [562993, 471166, 436765, 376271, 443955, 492609, 326566, 251272, 337061, 296070, 492943, 245535, 536729, 470490, 173328, 502494, 478500]
}

df = pd.DataFrame(data)
df
# Out:
#              직무    2022    2023    2024
# 0         IT기획자  419656  481654  562993
# 1        IT컨설턴트  476007  476404  471166
# 2         업무분석가  544972  532956  436765
# 3        데이터분석가  347476  380190  376271
# 4         IT PM  463265  456225  443955
# 5        IT아키텍트  518084  534135  492609
# 6   UI/UX기획/개발자  291414  315898  326566
# 7     UI/UX디자이너  217843  224150  251272
# 8       응용SW개발자  311962  341404  337061
# 9      시스템SW개발자  247590  278819  296070
# 10     정보시스템운용자  326653  435608  492943
# 11      IT지원기술자  190219  215203  245535
# 12        IT마케터  378726  483647  536729
# 13      IT품질관리자  402626  442826  470490
# 14        IT테스터  208959  189146  173328
# 15         IT감리  456540  485624  502494
# 16      정보보안전문가  362961  454136  478500

# %%
# ==========================================
# 활동 1. 연도별 대푯값 추이 및 2024년 집중 분석
# ==========================================
print("📊 [연도별 IT 직무 임금 대푯값 변화]")
print("-" * 50)

# 1) 2022~2024년 평균과 중앙값 변화 출력하기
for year in ['2022', '2023', '2024']:

    # TODO 1: 평균을 구하는 Pandas 함수를 입력하세요. (힌트: m _ _ _)
    mean_val = df[year].mean()

    # TODO 2: 중앙값을 구하는 Pandas 함수를 입력하세요. (힌트: m _ _ _ _ _)
    median_val = df[year].median()

    print(f"✅ {year}년 - 평균: {mean_val:,.0f}원 / 중앙값: {median_val:,.0f}원")

print("-" * 50)

# 2) 2024년 기준 세부 분석
# TODO 3: 2024년 데이터의 최빈값을 구하는 Pandas 함수를 입력하세요.
mode_2024 = df['2024'].mode()

print(f"✅ 2024년 최빈값(Mode): \n{mode_2024.to_string(index=False)} \n(※ 수치형 데이터라 중복값이 없어 모두 출력됨)")
print("-" * 50)

# 가장 높은 임금과 가장 낮은 임금 찾기 (2024년)
max_job = df.loc[df['2024'].idxmax(), '직무']
min_job = df.loc[df['2024'].idxmin(), '직무']

# TODO 4: 2024년 데이터 중 가장 높은 임금(최댓값)과 가장 낮은 임금(최솟값)을 구하는 함수를 입력하세요.
max_wage = df['2024'].max()
min_wage = df['2024'].min()

print(f"💰 2024년 최고 임금 직무: {max_job} ({max_wage:,.0f}원)")
print(f"📉 2024년 최저 임금 직무: {min_job} ({min_wage:,.0f}원)")
print(f"격차: {(max_wage - min_wage):,.0f}원\n")
# Out:
# 📊 [연도별 IT 직무 임금 대푯값 변화]
# --------------------------------------------------
# ✅ 2022년 - 평균: 362,644원 / 중앙값: 362,961원
# ✅ 2023년 - 평균: 395,766원 / 중앙값: 442,826원
# ✅ 2024년 - 평균: 405,573원 / 중앙값: 443,955원
# --------------------------------------------------
# ✅ 2024년 최빈값(Mode):
# 173328
# 245535
# 251272
# 296070
# 326566
# 337061
# 376271
# 436765
# 443955
# 470490
# 471166
# 478500
# 492609
# 492943
# 502494
# 536729
# 562993
# (※ 수치형 데이터라 중복값이 없어 모두 출력됨)
# --------------------------------------------------
# 💰 2024년 최고 임금 직무: IT기획자 (562,993원)
# 📉 2024년 최저 임금 직무: IT테스터 (173,328원)
# 격차: 389,665원

# %%
# ==========================================
# 활동 2. 데이터 시각화 (그래프 그리기)
# ==========================================
plt.figure(figsize=(18, 6))

# [그래프 1] 가로 막대그래프 (2024년 직무별 임금 비교)
plt.subplot(1, 3, 1)
df_sorted = df.sort_values(by='2024', ascending=True)

# TODO 5: 가로 막대그래프를 그리는 Matplotlib 함수를 작성하세요. (힌트: b_ _ _)
plt.barh(df_sorted['직무'], df_sorted['2024'], color='skyblue', edgecolor='black')

plt.title('2024년 IT 직무별 임금 (막대그래프)', fontsize=14)
plt.xlabel('임금', fontsize=12)
plt.ylabel('직무', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# %%
# [그래프 2] 히스토그램 (2024년 임금 데이터 분포 확인)
plt.subplot(1, 3, 2)
# TODO 6: 히스토그램을 그리는 Matplotlib 함수를 작성하세요. (힌트: h_ _ _)
plt.hist(df['2024'], bins=6, color='lightgreen', edgecolor='black', alpha=0.7)

# TODO 7: 히스토그램에 기준선으로 그릴 2024년 평균과 중앙값 함수를 입력하세요.
mean_2024 = df['2024'].mean()
median_2024 = df['2024'].quantile()

plt.axvline(mean_2024, color='red', linestyle='dashed', linewidth=2, label=f'24년 평균 ({mean_2024:,.0f})')
plt.axvline(median_2024, color='blue', linestyle='solid', linewidth=2, label=f'24년 중앙값 ({median_2024:,.0f})')
plt.title('2024년 IT 직무 임금 분포 (히스토그램)', fontsize=14)
plt.xlabel('임금 구간', fontsize=12)
plt.ylabel('직무 개수(빈도수)', fontsize=12)
plt.legend()
plt.show()

# %%
# [그래프 3] 선 그래프 (2022~2024년 대푯값 추이 확인)
plt.subplot(1, 3, 3)
years = ['2022', '2023', '2024']

# TODO 8: 연도별 대푯값을 리스트로 만드는 과정입니다. 평균과 중앙값 함수를 채워주세요.
means = [df[y].mean() for y in years]
medians = [df[y].quantile() for y in years]

# TODO 9: 선 그래프를 그리는 Matplotlib 함수를 작성하세요. (힌트: p_ _ _)
plt.plot(years, means, marker='o', color='red', linestyle='-', linewidth=2, label='평균(Mean)')
plt.plot(years, medians, marker='s', color='blue', linestyle='--', linewidth=2, label='중앙값(Median)')

for i, txt in enumerate(means):
    plt.text(years[i], means[i] + 5000, f'{txt:,.0f}', ha='center', va='bottom', fontsize=10, color='red')
for i, txt in enumerate(medians):
    plt.text(years[i], medians[i] - 10000, f'{txt:,.0f}', ha='center', va='top', fontsize=10, color='blue')

plt.title('연도별 임금 대푯값 추이 (선 그래프)', fontsize=14)
plt.xlabel('연도', fontsize=12)
plt.ylabel('임금', fontsize=12)
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# ==========================================
# 활동 2. 데이터 시각화 (그래프 그리기)
# ==========================================
plt.figure(figsize=(18, 6))

# [그래프 1] 가로 막대그래프 (2024년 직무별 임금 비교)
plt.subplot(1, 3, 1)
df_sorted = df.sort_values(by='2024', ascending=True)

# TODO 5: 가로 막대그래프를 그리는 Matplotlib 함수를 작성하세요. (힌트: b_ _ _)
plt.barh(df_sorted['직무'], df_sorted['2024'], color='skyblue', edgecolor='black')

plt.title('2024년 IT 직무별 임금 (막대그래프)', fontsize=14)
plt.xlabel('임금', fontsize=12)
plt.ylabel('직무', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# [그래프 2] 히스토그램 (2024년 임금 데이터 분포 확인)
plt.subplot(1, 3, 2)
# TODO 6: 히스토그램을 그리는 Matplotlib 함수를 작성하세요. (힌트: h_ _ _)
plt.hist(df['2024'], bins=6, color='lightgreen', edgecolor='black', alpha=0.7)

# TODO 7: 히스토그램에 기준선으로 그릴 2024년 평균과 중앙값 함수를 입력하세요.
mean_2024 = df['2024'].mean()
median_2024 = df['2024'].quantile()

plt.axvline(mean_2024, color='red', linestyle='dashed', linewidth=2, label=f'24년 평균 ({mean_2024:,.0f})')
plt.axvline(median_2024, color='blue', linestyle='solid', linewidth=2, label=f'24년 중앙값 ({median_2024:,.0f})')
plt.title('2024년 IT 직무 임금 분포 (히스토그램)', fontsize=14)
plt.xlabel('임금 구간', fontsize=12)
plt.ylabel('직무 개수(빈도수)', fontsize=12)
plt.legend()
plt.show()

# [그래프 3] 선 그래프 (2022~2024년 대푯값 추이 확인)
plt.subplot(1, 3, 3)
years = ['2022', '2023', '2024']

# TODO 8: 연도별 대푯값을 리스트로 만드는 과정입니다. 평균과 중앙값 함수를 채워주세요.
means = [df[y].mean() for y in years]
medians = [df[y].quantile() for y in years]

# TODO 9: 선 그래프를 그리는 Matplotlib 함수를 작성하세요. (힌트: p_ _ _)
plt.plot(years, means, marker='o', color='red', linestyle='-', linewidth=2, label='평균(Mean)')
plt.plot(years, medians, marker='s', color='blue', linestyle='--', linewidth=2, label='중앙값(Median)')

for i, txt in enumerate(means):
    plt.text(years[i], means[i] + 5000, f'{txt:,.0f}', ha='center', va='bottom', fontsize=10, color='red')
for i, txt in enumerate(medians):
    plt.text(years[i], medians[i] - 10000, f'{txt:,.0f}', ha='center', va='top', fontsize=10, color='blue')

plt.title('연도별 임금 대푯값 추이 (선 그래프)', fontsize=14)
plt.xlabel('연도', fontsize=12)
plt.ylabel('임금', fontsize=12)
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()
