# %% [markdown]
# <a href="https://colab.research.google.com/github/sechan-design/2026-data-science-and-machine-learning/blob/main/%EC%9C%A4%EC%84%B8%EC%B0%AC_%ED%8C%90%EB%8B%A4%EC%8A%A4_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas 실습 연습문제 1 (Google Colab 용)

import pandas as pd

# 예제 데이터 생성
data = {
    '학생번호': [101, 102, 103, 104, 105, 106],
    '이름': ['현우', '수빈', '정민', '지수', '민아', '준서'],
    '학년': [2, 1, 2, 3, 1, 3],
    '국어점수': [85, 90, 78, 92, 88, 80],
    '과학점수': [89, 94, 77, 86, 91, 83],
    '사회점수': [91, 87, 80, 90, 85, 82]
}

# 데이터프레임 생성

df=pd.DataFrame(data)


# ======== 연습문제 ========

# 문제 1: 전체 학생들의 국어, 과학, 사회 점수의 평균을 각각 구하세요.
# 정답:
print(df['국어점수'].mean())
print(df['과학점수'].mean())
print(df['사회점수'].mean())

# 문제 2: 3학년 학생들의 모든 정보를 출력하세요.
# 정답:
print(df[df['학년'] >1])

# 문제 3: "총점" 열을 추가하여 각 학생의 국어, 과학, 사회 점수 합계를 계산하세요.
# 정답:

df['총점']=df['국어점수'] +df['과학점수']+df['사회점수']
print(df['총점'])
# 문제 4: 총점이 가장 높은 학생의 이름과 학년을 출력하세요.
# 정답:


# 문제 5: 학년별로 사회점수의 평균을 구하여 출력하세요.
# 정답:


# 문제 6: 과학점수가 85점 이상이면서 국어점수가 80점 이상인 학생들의 이름을 출력하세요.
# 정답:


# 문제 7: 모든 학생의 데이터를 '학년'을 기준으로 오름차순으로 정렬하여 출력하세요.
# 정답:
# Out:
# 85.5
# 86.66666666666667
# 85.83333333333333
#    학생번호  이름  학년  국어점수  과학점수  사회점수
# 0   101  현우   2    85    89    91
# 2   103  정민   2    78    77    80
# 3   104  지수   3    92    86    90
# 5   106  준서   3    80    83    82
# 0    265
# 1    271
# 2    235
# 3    268
# 4    264
# 5    245
# Name: 총점, dtype: int64
#    학생번호  이름  학년  국어점수  과학점수  사회점수   총점
# 5   106  준서   3    80    83    82  245

# %%
# pandas 실습 연습문제 2 (Google Colab 용)

import pandas as pd

# 예제 데이터 생성
data = {
    '직원ID': [201, 202, 203, 204, 205],
    '이름': ['영철', '수지', '도윤', '민희', '정호'],
    '부서': ['마케팅', '영업', '기술', '영업', '기술'],
    '급여(만원)': [350, 400, 420, 380, 450],
    '근무년수': [3, 5, 2, 4, 6]
}

# 데이터프레임 생성


# 데이터프레임 확인


# ======== 연습문제 ========

# 문제 1: 직원들의 평균 급여를 구하세요.
# 정답:


# 문제 2: 가장 근무년수가 오래된 직원의 이름과 부서를 출력하세요.
# 정답:


# 문제 3: 부서별로 급여의 평균을 구하여 출력하세요.
# 정답:


# 문제 4: 급여가 400만원 이상인 직원들의 정보를 출력하세요.
# 정답:

# 문제 5: 근무년수가 3년 이상이면서 부서가 '영업'인 직원의 이름을 출력하세요.
# 정답:


# 문제 6: "연차수당" 열을 추가하고, 근무년수에 10만원을 곱하여 계산하세요.
# 정답:

# 문제 7: 직원 데이터를 급여를 기준으로 내림차순으로 정렬하여 출력하세요.
# 정답:
